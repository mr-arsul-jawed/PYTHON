# %%
import pandas as pd

data = pd.read_excel("Data/practice.xlsx")
# print(data)

data["Bonus"] = data["Salary"]/100*20
print(data)
# Out:
#   FirstName LastName  Salary   EEID    Bonus
# 0      Amit   Sharma   45000  E1001   9000.0
# 1      Neha    Verma   52000  E1002  10400.0
# 2     Rohit    Mehta   60000  E1003  12000.0
# 3     Priya    Singh   48000  E1004   9600.0
# 4     Karan    Patel   75000  E1005  15000.0
# 5     Sneha     Iyer   68000  E1006  13600.0
# 6     Arjun   Kapoor   55000  E1007  11000.0
# 7     Pooja     Nair   47000  E1008   9400.0
# 8    Vikram      Rao   82000  E1009  16400.0
# 9    Anjali    Gupta   39000  E1010   7800.0

# %%
data = {"Months":["january","February","March","April"]}

x = pd.DataFrame(data)
print(x)


def extra(values): #function
    return values[0:3]

x["sort_name_month"] = x["Months"].map(extra) #method
print(x)
# Out:
#      Months
# 0   january
# 1  February
# 2     March
# 3     April
#      Months sort_name_month
# 0   january             jan
# 1  February             Feb
# 2     March             Mar
# 3     April             Apr
