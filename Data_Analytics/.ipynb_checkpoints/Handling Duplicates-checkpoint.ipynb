# %%
import pandas as pd

data = pd.read_csv("Data/customers.csv")
print(data)
# Out:
#   Customer Id            Name Gender    Salary
# 0        DD37   Sheryl Baxter      f       NaN
# 1        DD38  Preston Lozano      m   40000.0
# 2        DD39       Roy Berry    NaN   60000.0
# 3        DD40     Linda Olsen      F       NaN
# 4        DD41   Joanna Bender      M  100000.0
# 5        DD37   Sheryl Baxter    NaN   20000.0

# %%
# print(data.duplicated()) # use to find duplicate values
# print(data["Customer Id"].duplicated()) #find duplicate with row
print(data["Customer Id"].duplicated().sum())
# Out:
# 1

# %%
print(data.drop_duplicates("Customer Id")) #use to remove duplicate
# Out:
#   Customer Id            Name Gender    Salary
# 0        DD37   Sheryl Baxter      f       NaN
# 1        DD38  Preston Lozano      m   40000.0
# 2        DD39       Roy Berry    NaN   60000.0
# 3        DD40     Linda Olsen      F       NaN
# 4        DD41   Joanna Bender      M  100000.0
