# %%
import matplotlib.pyplot as plt

brands  = ["OnePlus", "Samsung", "Apple", "Xiaomi", "Vivo"]
x = [22, 34, 30, 35, 27]

print("Brands: ", brands)

# plt.pie(x, labels=brands, autopct='%1.1f%%', startangle=140)
# plt.show()
